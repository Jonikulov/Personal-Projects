# %% [markdown]
# # Data Analysis Project 6: India Census 2011 Dataset
#
# - https://youtu.be/e1zKFSrKeLs?list=PLy3lFw0OTlutzXFVwttrtaRGEEyLEdnpy

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/india_census.csv")
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %% [markdown]
# ## Q1: How will you hide the indexes of the dataframe.

# %%
df.sample(15).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_97f3d">
#   <thead>
#     <tr>
#       <th id="T_97f3d_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_97f3d_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_97f3d_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_97f3d_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_97f3d_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_97f3d_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_97f3d_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_97f3d_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_97f3d_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
#       <th id="T_97f3d_level0_col9" class="col_heading level0 col9" >Female_Workers</th>
# ...

# %% [markdown]
# ## Q2: How can we set the caption / heading on the dataframe.

# %%
df.sample(10).style.set_caption("Sample Caption")
# Out:
# <style type="text/css">
# </style>
# <table id="T_72367">
#   <caption>Sample Caption</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72367_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_72367_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_72367_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_72367_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_72367_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_72367_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_72367_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_72367_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_72367_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# ## Q3: Show the records related with the districts - New Delhi , Lucknow , Jaipur.

# %%
df[df['District_name'].isin(['New Delhi', 'Lucknow', 'Jaipur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 93              94   NCT OF DELHI     New Delhi      142004    77942    64062
# 109            110      RAJASTHAN        Jaipur     6626178  3468507  3157671
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 109   4300965  2464893       1714947          749946  ...       12708  18782
# 156   3127260  1542806       1226399          316407  ...       20493  23883
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 109       1020  81079               659389            455527
# 156       3877   4975               428121            378742
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ## Q4: Calculate state-wise:
# ### - Total number of population.
# ### - Total no. of the population with different religions.

# %%
cols = ["Population", "Hindus", "Muslims", "Christians", "Sikhs", "Buddhists", "Jains"]
df.groupby('State_name')[cols].sum()
# Out:
#                              Population     Hindus   Muslims  Christians  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS      380581     264296     32413       80984
# ANDHRA PRADESH                 84580777   74824149   8082412     1129784
# ARUNACHAL PRADESH               1383727     401876     27045      418732
# ASSAM                          31205576   19180759  10679345     1165867
# BIHAR                         104099452   86078686  17557809      129247
# CHANDIGARH                      1055450     852574     51447        8720
# CHHATTISGARH                   25545198   23819789    514998      490542
# DADRA AND NAGAR HAVELI           343709     322857     12922        5113
# DAMAN AND DIU                    243247     220150     19277        2820
# GOA                             1458545     963877    121564      366130
# GUJARAT                        60439692   53533988   5846761      316178
# HARYANA                        25351462   22171128   1781342       50353
# ...

# %% [markdown]
# ## Q5: How many Male Workers were there in Maharashtra state ?

# %%
df[df['State_name']=='MAHARASHTRA'][['Male_Workers']].sum()
# Out:
# Male_Workers    32616875
# dtype: int64

# %% [markdown]
# ## Q6: How to set a column as index of the dataframe ?

# %%
df.set_index(['State_name'])
# Out:
#                              District_code              District_name  \
# State_name
# JAMMU AND KASHMIR                        1                    Kupwara
# JAMMU AND KASHMIR                        2                     Badgam
# JAMMU AND KASHMIR                        3                Leh(Ladakh)
# JAMMU AND KASHMIR                        4                     Kargil
# JAMMU AND KASHMIR                        5                      Punch
# ...                                    ...                        ...
# PONDICHERRY                            636                       Mahe
# PONDICHERRY                            637                   Karaikal
# ANDAMAN AND NICOBAR ISLANDS            638                   Nicobars
# ANDAMAN AND NICOBAR ISLANDS            639  North  AND Middle Andaman
# ANDAMAN AND NICOBAR ISLANDS            640              South Andaman
#
#                              Population    Male  Female  Literate  Workers  \
# State_name
# ...

# %% [markdown]
# ## Q7: Add a Suffix to the column names.

# %%
# df.rename(columns=lambda x: x+"_0")
df.add_suffix("_right")
# Out:
#      District_code_right             State_name_right  \
# 0                      1            JAMMU AND KASHMIR
# 1                      2            JAMMU AND KASHMIR
# 2                      3            JAMMU AND KASHMIR
# 3                      4            JAMMU AND KASHMIR
# 4                      5            JAMMU AND KASHMIR
# ..                   ...                          ...
# 635                  636                  PONDICHERRY
# 636                  637                  PONDICHERRY
# 637                  638  ANDAMAN AND NICOBAR ISLANDS
# 638                  639  ANDAMAN AND NICOBAR ISLANDS
# 639                  640  ANDAMAN AND NICOBAR ISLANDS
#
#            District_name_right  Population_right  Male_right  Female_right  \
# 0                      Kupwara            870354      474190        396164
# 1                       Badgam            753745      398041        355704
# 2                  Leh(Ladakh)            133487       78971         54516
# ...

# %% [markdown]
# ## Q8: Add a Prefix to the column names.

# %%
# df.rename(columns=lambda x: "0_"+x)
df.add_prefix("left_")
# Out:
#      left_District_code              left_State_name  \
# 0                     1            JAMMU AND KASHMIR
# 1                     2            JAMMU AND KASHMIR
# 2                     3            JAMMU AND KASHMIR
# 3                     4            JAMMU AND KASHMIR
# 4                     5            JAMMU AND KASHMIR
# ..                  ...                          ...
# 635                 636                  PONDICHERRY
# 636                 637                  PONDICHERRY
# 637                 638  ANDAMAN AND NICOBAR ISLANDS
# 638                 639  ANDAMAN AND NICOBAR ISLANDS
# 639                 640  ANDAMAN AND NICOBAR ISLANDS
#
#             left_District_name  left_Population  left_Male  left_Female  \
# 0                      Kupwara           870354     474190       396164
# 1                       Badgam           753745     398041       355704
# 2                  Leh(Ladakh)           133487      78971        54516
# ...
