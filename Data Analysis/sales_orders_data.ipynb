# %% [markdown]
# # Data Analysis Project 10: Making Python Projects Easier with Mito
#
# - https://youtu.be/bHE5bfRxmAM?list=PLy3lFw0OTlutzXFVwttrtaRGEEyLEdnpy
# - Mito Documentation: https://docs.trymito.io/

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/sales_orders_2014.csv")
df
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %% [markdown]
# ## 1. Add a new column `quantity_10`: quantity * 10

# %%
df['quantity_10'] = df['quantity'] * 10
df.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  quantity_10
# ...

# %% [markdown]
# ## 2. Add a new column a particular place

# %%
# Adding `new_column` after the `region` column
df.insert(loc=6, column='new_column', value=df['discount']*100)
df.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region  new_column        product_id         category  \
# 0   Africa         0.0  OFF-TEN-10000025  Office Supplies
# 1  Oceania        10.0   OFF-SU-10000618  Office Supplies
# 2     EMEA         0.0  OFF-TEN-10001585  Office Supplies
# 3    North        50.0   OFF-PA-10001492  Office Supplies
# 4  Oceania        10.0   FUR-FU-10003447        Furniture
#
#                   product_name sales  quantity  discount   profit  year  \
# 0          Tenex Lockers, Blue   408         2       0.0  106.140  2011
# ...

# %% [markdown]
# ## 3. Delete a column

# %%
df.drop(columns=['new_column', 'quantity_10'], inplace=True)
df.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year
# ...

# %% [markdown]
# ## 4. Sorting a DataFrame

# %%
df['order_date'] = pd.to_datetime(df['order_date'],
                                  format='%m-%d-%Y',
                                  infer_datetime_format=True)

df.sort_values(by=['order_date', 'region'])
# Out:
#               order_id order_date     customer_name      segment  \
# 0         AG-2011-2040 2011-01-01   Toby Braunhardt     Consumer
# 2         HU-2011-1220 2011-01-01     Annie Thurman     Consumer
# 3      IT-2011-3647632 2011-01-01      Eugene Moren  Home Office
# 1        IN-2011-47883 2011-01-01       Joseph Holt     Consumer
# 4        IN-2011-47883 2011-01-01       Joseph Holt     Consumer
# ...                ...        ...               ...          ...
# 51266    IN-2014-30390 2014-12-31  Justin Deggeller    Corporate
# 51275    ID-2014-54442 2014-12-31   Muhammed Yedwab    Corporate
# 51281   CA-2014-115427 2014-12-31        Erica Bern    Corporate
# 51285   CA-2014-115427 2014-12-31        Erica Bern    Corporate
# 51289   CA-2014-156720 2014-12-31     Jill Matthias     Consumer
#
#              country          region        product_id         category  \
# 0            Algeria          Africa  OFF-TEN-10000025  Office Supplies
# ...

# %% [markdown]
# ## 5. Filter DataFrame (single column / condition)

# %%
df[df['country']=='Uzbekistan'].head()
# Out:
#           order_id order_date    customer_name      segment     country  \
# 5978  UZ-2011-8840 2011-10-07        Ed Ludwig  Home Office  Uzbekistan
# 5988  UZ-2011-8840 2011-10-07        Ed Ludwig  Home Office  Uzbekistan
# 5990  UZ-2011-8840 2011-10-07        Ed Ludwig  Home Office  Uzbekistan
# 5994  UZ-2011-8840 2011-10-07        Ed Ludwig  Home Office  Uzbekistan
# 6116  UZ-2011-1000 2011-10-12  Ricardo Sperren    Corporate  Uzbekistan
#
#      region        product_id         category  \
# 5978   EMEA  TEC-CIS-10003017       Technology
# 5988   EMEA  TEC-BEL-10001971       Technology
# 5990   EMEA  OFF-ROG-10002818  Office Supplies
# 5994   EMEA  OFF-ELD-10001037  Office Supplies
# 6116   EMEA  OFF-KLE-10002550  Office Supplies
#
#                               product_name sales  quantity  discount  profit  \
# 5978  Cisco Signal Booster, with Caller ID   152         1       0.0   37.95
# 5988               Belkin Flash Drive, USB    42         1       0.0   13.89
# ...

# %% [markdown]
# ## 6. Filter DataFrame (multiple columns / conditions) - AND operator

# %%
filter_df = (df['segment']=='Home Office') & (df['category']=='Technology')
df[filter_df]
# Out:
#               order_id order_date    customer_name      segment  \
# 13       IN-2011-33652 2011-01-03    Dennis Pardue  Home Office
# 35      MX-2011-159373 2011-01-04  Arthur Wiediger  Home Office
# 60      CA-2011-167199 2011-01-07    Maria Etezadi  Home Office
# 67      CA-2011-167199 2011-01-07    Maria Etezadi  Home Office
# 84       IN-2011-19330 2011-01-08     Nicole Fjeld  Home Office
# ...                ...        ...              ...          ...
# 50914  ES-2014-5314666 2014-12-26      Mark Packer  Home Office
# 51026   MX-2014-128566 2014-12-28    Tracy Collins  Home Office
# 51044  IT-2014-5778325 2014-12-29     Joel Jenkins  Home Office
# 51236  ES-2014-5281275 2014-12-31  Shirley Schmidt  Home Office
# 51244  IT-2014-3715679 2014-12-31         Jim Kriz  Home Office
#
#              country          region       product_id    category  \
# 13          Malaysia  Southeast Asia  TEC-CO-10000594  Technology
# ...

# %% [markdown]
# ## 7. Filter DataFrame (multiple columns / conditions) - OR operator

# %%
filter_df = (df['country']=='Uzbekistan') | (df['region']=='Central')
df[filter_df]
# Out:
#               order_id order_date     customer_name      segment  \
# 15      MX-2011-160234 2011-01-03  Stewart Visinsky     Consumer
# 30     ES-2011-4939443 2011-01-04    Arthur Prichep     Consumer
# 38      CA-2011-103800 2011-01-04     Darren Powers     Consumer
# 44     ES-2011-3848439 2011-01-05  Michael Granlund  Home Office
# 45     ES-2011-3848439 2011-01-05  Michael Granlund  Home Office
# ...                ...        ...               ...          ...
# 51267  IT-2014-3715679 2014-12-31          Jim Kriz  Home Office
# 51272  IT-2014-3715679 2014-12-31          Jim Kriz  Home Office
# 51277   MX-2014-141712 2014-12-31      Rick Bensley  Home Office
# 51279  ES-2014-4785777 2014-12-31     Dennis Pardue  Home Office
# 51287   MX-2014-110527 2014-12-31  Charlotte Melton     Consumer
#
#              country   region       product_id         category  \
# 15         Guatemala  Central  TEC-PH-10002647       Technology
# ...

# %% [markdown]
# ## 8. Pivot Table

# %%
df['sales'] = df['sales'].str.replace(',', '')
df['sales'] = df['sales'].astype(int)

df.pivot_table(values='profit',
               index='region',
               columns=df['order_date'].dt.to_period('Y'),
               aggfunc='mean',
               fill_value=0
)
# Out:
# order_date           2011       2012       2013       2014
# region
# Africa          13.906117  13.502194  20.623734  24.218885
# Canada          29.146452  54.919551  48.391132  47.189055
# Caribbean       15.082730  25.162592  17.560742  23.037897
# Central         26.863066  27.071195  31.877129  26.052672
# Central Asia    63.816888  65.559007  64.792920  64.514896
# EMEA             6.270819   5.074508   8.102479  12.479472
# East            32.997310  32.750020  26.374917  36.003629
# North           45.747739  46.404687  40.512617  34.526721
# North Asia      76.208955  57.301270  78.337498  69.987322
# Oceania         39.318826  37.468841  40.889220  26.346669
# South           15.467160  21.086021  22.012811  23.364694
# Southeast Asia   5.669574   4.199580   3.992691   7.828239
# West            30.356568  31.919306  29.912531  39.945974

# %% [markdown]
# ## 9. Scatter Plot

# %%
plt.scatter(df.sales, df.profit, s=45, color='r', edgecolors='purple', label="Scatter Chart")
plt.xlabel("Sales")
plt.ylabel("Profit")
# plt.grid(alpha=0.2)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## 10. Concatenate 2 columns

# %%
df['con_col'] = df['country'] + '(' + df['region'] + ')'
df
# Out:
#               order_id order_date     customer_name      segment  \
# 0         AG-2011-2040 2011-01-01   Toby Braunhardt     Consumer
# 1        IN-2011-47883 2011-01-01       Joseph Holt     Consumer
# 2         HU-2011-1220 2011-01-01     Annie Thurman     Consumer
# 3      IT-2011-3647632 2011-01-01      Eugene Moren  Home Office
# 4        IN-2011-47883 2011-01-01       Joseph Holt     Consumer
# ...                ...        ...               ...          ...
# 51285   CA-2014-115427 2014-12-31        Erica Bern    Corporate
# 51286     MO-2014-2560 2014-12-31         Liz Preis     Consumer
# 51287   MX-2014-110527 2014-12-31  Charlotte Melton     Consumer
# 51288   MX-2014-114783 2014-12-31     Tamara Dahlen     Consumer
# 51289   CA-2014-156720 2014-12-31     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...
